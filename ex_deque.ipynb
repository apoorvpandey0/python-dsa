# %% [markdown]
# # Deque(deck)
# The deque object is typically used to perform fast operations on the beginning and and of a list. It should only be used when you care more about manipulating data and taking items from the beginning and end of the list rather than random lookups of elements.
#
# To create a new deque we can do the following:

# %%
from collections import deque

d = deque("hello")  # Takes and iterable argument
print(d)  # prints deque(["h", "e", "l", "l","o"])
# Out:
# deque(['h', 'e', 'l', 'l', 'o'])

# %% [markdown]
# # Manipulation
# The deque object allows for appending to the beginning and end of the deque. It also allows us to pop elements from either end

# %%
from collections import deque

d = deque("hello")  # Takes and iterable argument
d.appendleft(5)  # d is now deque([5, "h", "e", "l","l", "o"])
d.append(4)  # d is now deque([5, "h", "e", "l","l", "o", 4])

d.pop()  # would return 4
d.popleft()  # would return 5
# Out:
# 5

# %% [markdown]
# # More Methods
# The deque object also has some other useful methods.
#
# 1. .clear(): This will empty the deque object.

# %%
from collections import deque

d = deque("hello")  # Takes and iterable d.clear()

print(d) # prints deque([])
# Out:
# deque(['h', 'e', 'l', 'l', 'o'])

# %% [markdown]
# 2. .extend(iterable): This will add all of the items from the passed iterbale data type or collection to the end of the deque. .extendleft() words the same way

# %%
from collections import deque

d = deque("hello")  # Takes and iterable 
d.extend("12")
d.extend([7,8])
d.extendleft(100)

print(d) # prints deque([100,"h", "e", "l", "l", "o","1", "2", 7, 8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# f:\Projects\DSA\python-dsa\ex_deque.ipynb Cell 8' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/f%3A/Projects/DSA/python-dsa/ex_deque.ipynb#ch0000007?line=3'>4</a> d.extend("12")
#       <a href='vscode-notebook-cell:/f%3A/Projects/DSA/python-dsa/ex_deque.ipynb#ch0000007?line=4'>5</a> d.extend([7,8])
# ----> <a href='vscode-notebook-cell:/f%3A/Projects/DSA/python-dsa/ex_deque.ipynb#ch0000007?line=5'>6</a> d.extendleft(100)
#       <a href='vscode-notebook-cell:/f%3A/Projects/DSA/python-dsa/ex_deque.ipynb#ch0000007?line=7'>8</a> print(d)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# 3. .rot3ate(n): Given an int n this method will rotate the deck that many positions. The given int can be negative or positive. If it is negative it will rotate the deque to the left, otherwise it will rotate to the right.

# %%
from collections import deque

d = deque("hello")  # Takes and iterable 
d.rotate(1)

print(d) # prints deque(["o", "h", "e", "l", "l"])

d.rotate(-2)

print(d)  # prints deque(["e", "l", "l", "o", "h"])

# %% [markdown]
# # Useful parameter: Max length of deque
# You can also define amaxlen param to limit this size of your deque

# %%
from collections import deque
# TODO: Complete this
d = deque("hello",maxlen=5)  # Takes and iterable
d.append(4) # Will remove h from the front and add 4 to the back
